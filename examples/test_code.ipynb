# %%
from biomapper2.mapper import Mapper

mapper = Mapper()

mapper.map_dataset_to_kg(
    dataset_tsv_path='../data/examples/olink_protein_metadata.tsv',
    entity_type='protein',
    name_column='Assay',
    provided_id_columns=['UniProt'],
    array_delimiters=['_']
)
# Out:
# 2025-11-18 14:11:43,493 - root - INFO - Beginning to map dataset to KG (../data/examples/olink_protein_metadata.tsv)
# 2025-11-18 14:11:43,552 - root - INFO - After step 1 (annotation), df is:
#         Assay UniProt               Panel assigned_ids
# 0      AARSD1  Q9BTE6            Oncology           {}
# 1     ABHD14B  Q96IU4           Neurology           {}
# 2        ABL1  P00519            Oncology           {}
# 3       ACAA1  P09110            Oncology           {}
# 4        ACAN  P16112     Cardiometabolic           {}
# ...       ...     ...                 ...          ...
# 2918    ZNRD2  O60232         Oncology II           {}
# 2919    ZNRF4  Q8WWF5         Oncology II           {}
# 2920      ZP3  P21754  Cardiometabolic II           {}
# 2921      ZP4  Q12836         Oncology II           {}
# 2922     ZPR1  O75312        Neurology II           {}
#
# [2923 rows x 4 columns]
# 2025-11-18 14:11:43,643 - root - WARNING - Local id 'NTproBNP' is invalid for ['uniprotkb']. Skipping.
# 2025-11-18 14:11:43,708 - root - INFO - After step 2 (normalization), df is:
#         Assay UniProt               Panel assigned_ids              curies  \
# 0      AARSD1  Q9BTE6            Oncology           {}  [UniProtKB:Q9BTE6]
# 1     ABHD14B  Q96IU4           Neurology           {}  [UniProtKB:Q96IU4]
# 2        ABL1  P00519            Oncology           {}  [UniProtKB:P00519]
# 3       ACAA1  P09110            Oncology           {}  [UniProtKB:P09110]
# 4        ACAN  P16112     Cardiometabolic           {}  [UniProtKB:P16112]
# ...       ...     ...                 ...          ...                 ...
# 2918    ZNRD2  O60232         Oncology II           {}  [UniProtKB:O60232]
# 2919    ZNRF4  Q8WWF5         Oncology II           {}  [UniProtKB:Q8WWF5]
# 2920      ZP3  P21754  Cardiometabolic II           {}  [UniProtKB:P21754]
# 2921      ZP4  Q12836         Oncology II           {}  [UniProtKB:Q12836]
# 2922     ZPR1  O75312        Neurology II           {}  [UniProtKB:O75312]
#
#          curies_provided curies_assigned invalid_ids invalid_ids_provided  \
# 0     [UniProtKB:Q9BTE6]              []          {}                   {}
# 1     [UniProtKB:Q96IU4]              []          {}                   {}
# 2     [UniProtKB:P00519]              []          {}                   {}
# 3     [UniProtKB:P09110]              []          {}                   {}
# 4     [UniProtKB:P16112]              []          {}                   {}
# ...                  ...             ...         ...                  ...
# 2918  [UniProtKB:O60232]              []          {}                   {}
# 2919  [UniProtKB:Q8WWF5]              []          {}                   {}
# 2920  [UniProtKB:P21754]              []          {}                   {}
# 2921  [UniProtKB:Q12836]              []          {}                   {}
# 2922  [UniProtKB:O75312]              []          {}                   {}
#
#      invalid_ids_assigned
# 0                      {}
# 1                      {}
# 2                      {}
# 3                      {}
# 4                      {}
# ...                   ...
# 2918                   {}
# 2919                   {}
# 2920                   {}
# 2921                   {}
# 2922                   {}
#
# [2923 rows x 10 columns]
# 2025-11-18 14:11:44,874 - root - INFO - After step 3 (linking), df is:
#         Assay UniProt               Panel assigned_ids              curies  \
# 0      AARSD1  Q9BTE6            Oncology           {}  [UniProtKB:Q9BTE6]
# 1     ABHD14B  Q96IU4           Neurology           {}  [UniProtKB:Q96IU4]
# 2        ABL1  P00519            Oncology           {}  [UniProtKB:P00519]
# 3       ACAA1  P09110            Oncology           {}  [UniProtKB:P09110]
# 4        ACAN  P16112     Cardiometabolic           {}  [UniProtKB:P16112]
# ...       ...     ...                 ...          ...                 ...
# 2918    ZNRD2  O60232         Oncology II           {}  [UniProtKB:O60232]
# 2919    ZNRF4  Q8WWF5         Oncology II           {}  [UniProtKB:Q8WWF5]
# 2920      ZP3  P21754  Cardiometabolic II           {}  [UniProtKB:P21754]
# 2921      ZP4  Q12836         Oncology II           {}  [UniProtKB:Q12836]
# 2922     ZPR1  O75312        Neurology II           {}  [UniProtKB:O75312]
#
#          curies_provided curies_assigned invalid_ids invalid_ids_provided  \
# 0     [UniProtKB:Q9BTE6]              []          {}                   {}
# 1     [UniProtKB:Q96IU4]              []          {}                   {}
# 2     [UniProtKB:P00519]              []          {}                   {}
# 3     [UniProtKB:P09110]              []          {}                   {}
# 4     [UniProtKB:P16112]              []          {}                   {}
# ...                  ...             ...         ...                  ...
# 2918  [UniProtKB:O60232]              []          {}                   {}
# 2919  [UniProtKB:Q8WWF5]              []          {}                   {}
# 2920  [UniProtKB:P21754]              []          {}                   {}
# 2921  [UniProtKB:Q12836]              []          {}                   {}
# 2922  [UniProtKB:O75312]              []          {}                   {}
#
#      invalid_ids_assigned                                      kg_ids  \
# 0                      {}  {'UniProtKB:Q9BTE6': ['UniProtKB:Q9BTE6']}
# 1                      {}    {'NCBIGene:84836': ['UniProtKB:Q96IU4']}
# 2                      {}       {'NCBIGene:25': ['UniProtKB:P00519']}
# 3                      {}       {'NCBIGene:30': ['UniProtKB:P09110']}
# 4                      {}      {'NCBIGene:176': ['UniProtKB:P16112']}
# ...                   ...                                         ...
# 2918                   {}    {'NCBIGene:10534': ['UniProtKB:O60232']}
# 2919                   {}   {'NCBIGene:148066': ['UniProtKB:Q8WWF5']}
# 2920                   {}     {'NCBIGene:7784': ['UniProtKB:P21754']}
# 2921                   {}    {'NCBIGene:57829': ['UniProtKB:Q12836']}
# 2922                   {}     {'NCBIGene:8882': ['UniProtKB:O75312']}
#
#                                  kg_ids_provided kg_ids_assigned
# 0     {'UniProtKB:Q9BTE6': ['UniProtKB:Q9BTE6']}              {}
# 1       {'NCBIGene:84836': ['UniProtKB:Q96IU4']}              {}
# 2          {'NCBIGene:25': ['UniProtKB:P00519']}              {}
# 3          {'NCBIGene:30': ['UniProtKB:P09110']}              {}
# 4         {'NCBIGene:176': ['UniProtKB:P16112']}              {}
# ...                                          ...             ...
# 2918    {'NCBIGene:10534': ['UniProtKB:O60232']}              {}
# 2919   {'NCBIGene:148066': ['UniProtKB:Q8WWF5']}              {}
# 2920     {'NCBIGene:7784': ['UniProtKB:P21754']}              {}
# 2921    {'NCBIGene:57829': ['UniProtKB:Q12836']}              {}
# 2922     {'NCBIGene:8882': ['UniProtKB:O75312']}              {}
#
# [2923 rows x 13 columns]
# 2025-11-18 14:11:44,931 - root - INFO - After step 4 (resolution), df is:
#         Assay UniProt               Panel assigned_ids              curies  \
# 0      AARSD1  Q9BTE6            Oncology           {}  [UniProtKB:Q9BTE6]
# 1     ABHD14B  Q96IU4           Neurology           {}  [UniProtKB:Q96IU4]
# 2        ABL1  P00519            Oncology           {}  [UniProtKB:P00519]
# 3       ACAA1  P09110            Oncology           {}  [UniProtKB:P09110]
# 4        ACAN  P16112     Cardiometabolic           {}  [UniProtKB:P16112]
# ...       ...     ...                 ...          ...                 ...
# 2918    ZNRD2  O60232         Oncology II           {}  [UniProtKB:O60232]
# 2919    ZNRF4  Q8WWF5         Oncology II           {}  [UniProtKB:Q8WWF5]
# 2920      ZP3  P21754  Cardiometabolic II           {}  [UniProtKB:P21754]
# 2921      ZP4  Q12836         Oncology II           {}  [UniProtKB:Q12836]
# 2922     ZPR1  O75312        Neurology II           {}  [UniProtKB:O75312]
#
#          curies_provided curies_assigned invalid_ids invalid_ids_provided  \
# 0     [UniProtKB:Q9BTE6]              []          {}                   {}
# 1     [UniProtKB:Q96IU4]              []          {}                   {}
# 2     [UniProtKB:P00519]              []          {}                   {}
# 3     [UniProtKB:P09110]              []          {}                   {}
# 4     [UniProtKB:P16112]              []          {}                   {}
# ...                  ...             ...         ...                  ...
# 2918  [UniProtKB:O60232]              []          {}                   {}
# 2919  [UniProtKB:Q8WWF5]              []          {}                   {}
# 2920  [UniProtKB:P21754]              []          {}                   {}
# 2921  [UniProtKB:Q12836]              []          {}                   {}
# 2922  [UniProtKB:O75312]              []          {}                   {}
#
#      invalid_ids_assigned                                      kg_ids  \
# 0                      {}  {'UniProtKB:Q9BTE6': ['UniProtKB:Q9BTE6']}
# 1                      {}    {'NCBIGene:84836': ['UniProtKB:Q96IU4']}
# 2                      {}       {'NCBIGene:25': ['UniProtKB:P00519']}
# 3                      {}       {'NCBIGene:30': ['UniProtKB:P09110']}
# 4                      {}      {'NCBIGene:176': ['UniProtKB:P16112']}
# ...                   ...                                         ...
# 2918                   {}    {'NCBIGene:10534': ['UniProtKB:O60232']}
# 2919                   {}   {'NCBIGene:148066': ['UniProtKB:Q8WWF5']}
# 2920                   {}     {'NCBIGene:7784': ['UniProtKB:P21754']}
# 2921                   {}    {'NCBIGene:57829': ['UniProtKB:Q12836']}
# 2922                   {}     {'NCBIGene:8882': ['UniProtKB:O75312']}
#
#                                  kg_ids_provided kg_ids_assigned  \
# 0     {'UniProtKB:Q9BTE6': ['UniProtKB:Q9BTE6']}              {}
# 1       {'NCBIGene:84836': ['UniProtKB:Q96IU4']}              {}
# 2          {'NCBIGene:25': ['UniProtKB:P00519']}              {}
# 3          {'NCBIGene:30': ['UniProtKB:P09110']}              {}
# 4         {'NCBIGene:176': ['UniProtKB:P16112']}              {}
# ...                                          ...             ...
# 2918    {'NCBIGene:10534': ['UniProtKB:O60232']}              {}
# 2919   {'NCBIGene:148066': ['UniProtKB:Q8WWF5']}              {}
# 2920     {'NCBIGene:7784': ['UniProtKB:P21754']}              {}
# 2921    {'NCBIGene:57829': ['UniProtKB:Q12836']}              {}
# 2922     {'NCBIGene:8882': ['UniProtKB:O75312']}              {}
#
#           chosen_kg_id chosen_kg_id_provided chosen_kg_id_assigned
# 0     UniProtKB:Q9BTE6      UniProtKB:Q9BTE6                  None
# 1       NCBIGene:84836        NCBIGene:84836                  None
# 2          NCBIGene:25           NCBIGene:25                  None
# 3          NCBIGene:30           NCBIGene:30                  None
# 4         NCBIGene:176          NCBIGene:176                  None
# ...                ...                   ...                   ...
# 2918    NCBIGene:10534        NCBIGene:10534                  None
# 2919   NCBIGene:148066       NCBIGene:148066                  None
# 2920     NCBIGene:7784         NCBIGene:7784                  None
# 2921    NCBIGene:57829        NCBIGene:57829                  None
# 2922     NCBIGene:8882         NCBIGene:8882                  None
#
# [2923 rows x 16 columns]
# 2025-11-18 14:11:44,931 - root - INFO - Dumping output TSV to ../data/examples/olink_protein_metadata_MAPPED.tsv
# 2025-11-18 14:11:44,953 - root - INFO - Analyzing dataset KG mapping in ../data/examples/olink_protein_metadata_MAPPED.tsv
# 2025-11-18 14:11:45,195 - root - INFO - Dataset summary stats are: {
#   "mapped_dataset": "../data/examples/olink_protein_metadata_MAPPED.tsv",
#   "total_items": 2923,
#   "mapped_to_kg": 2922,
#   "mapped_to_kg_provided": 2922,
#   "mapped_to_kg_assigned": 0,
#   "mapped_to_kg_provided_and_assigned": 0,
#   "one_to_one_mappings": 2917,
#   "multi_mappings": 5,
#   "one_to_many_mappings": 5,
#   "many_to_one_mappings": 0,
#   "has_valid_ids": 2922,
#   "has_valid_ids_provided": 2922,
#   "has_valid_ids_assigned": 0,
#   "has_only_provided_ids": 2922,
#   "has_only_assigned_ids": 0,
#   "has_both_provided_and_assigned_ids": 0,
#   "assigned_mappings_correct_per_provided": 0,
#   "assigned_mappings_correct_per_provided_chosen": 0,
#   "has_invalid_ids": 1,
#   "has_invalid_ids_provided": 1,
#   "has_invalid_ids_assigned": 0,
#   "has_no_ids": 0,
#   "has_invalid_ids_and_not_mapped_to_kg": 1,
#   "performance": {
#     "overall": {
#       "coverage": 0.9996578857338351,
#       "coverage_explanation": "2922 / 2923"
#     },
#     "assigned_ids": {
#       "coverage": 0.0,
#       "coverage_explanation": "0 / 2923",
#       "per_provided_ids": {
#         "precision": null,
#         "precision_explanation": "0 / 0",
#         "recall": 0.0,
#         "recall_explanation": "0 / 2922",
#         "f1_score": null,
#         "after_resolving_one_to_manys": {
#           "precision": null,
#           "precision_explanation": "0 / 0",
#           "recall": 0.0,
#           "recall_explanation": "0 / 2922",
#           "f1_score": null
#         }
#       }
#     }
#   }
# }
# ('../data/examples/olink_protein_metadata_MAPPED.tsv',
#  {'mapped_dataset': '../data/examples/olink_protein_metadata_MAPPED.tsv',
#   'total_items': 2923,
#   'mapped_to_kg': 2922,
#   'mapped_to_kg_provided': 2922,
#   'mapped_to_kg_assigned': 0,
#   'mapped_to_kg_provided_and_assigned': 0,
#   'one_to_one_mappings': 2917,
#   'multi_mappings': 5,
#   'one_to_many_mappings': 5,
#   'many_to_one_mappings': 0,
#   'has_valid_ids': 2922,
#   'has_valid_ids_provided': 2922,
#   'has_valid_ids_assigned': 0,
#   'has_only_provided_ids': 2922,
#   'has_only_assigned_ids': 0,
#   'has_both_provided_and_assigned_ids': 0,
#   'assigned_mappings_correct_per_provided': 0,
#   'assigned_mappings_correct_per_provided_chosen': 0,
#   'has_invalid_ids': 1,
#   'has_invalid_ids_provided': 1,
#   'has_invalid_ids_assigned': 0,
#   'has_no_ids': 0,
#   'has_invalid_ids_and_not_mapped_to_kg': 1,
#   'performance': {'overall': {'coverage': 0.9996578857338351,
#     'coverage_explanation': '2922 / 2923'},
#    'assigned_ids': {'coverage': 0.0,
#     'coverage_explanation': '0 / 2923',
#     'per_provided_ids': {'precision': None,
#      'precision_explanation': '0 / 0',
#      'recall': 0.0,
#      'recall_explanation': '0 / 2922',
#      'f1_score': None,
#      'after_resolving_one_to_manys': {'precision': None,
#       'precision_explanation': '0 / 0',
#       'recall': 0.0,
#       'recall_explanation': '0 / 2922',
#       'f1_score': None}}}}})
